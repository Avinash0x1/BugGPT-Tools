# %% [markdown]
# # !! aws Sagemaker PERSISTS your SETTINGS & FILES
# # !! This is a ONE TIME PROCESS ONLY (at least the `setup_main.sh`)
# # 1. RUN this `first`
# # 2. Scroll until it says `Initialized`
# # 3. Open Terminal: Top Bar >> File >> NEW >> Terminal
# # Copy Paste (remove #)
# # bash "$HOME/.scripts/setup_main.sh"
# # Enter `Y` when prompted
# # After `Setup` finishes, type `zsh`
# # Enable `tmux` : `tmux`
# # Source file : `tmux source-file ~/.tmux.conf`
# # Install Plugins : `Alt + G + (Shift) I` >> Enter
# #-----------------------------

# %%
# sudo | apt | root | su --> Disabled
# pkgs are installed via conda | pip
# Reference : https://github.com/aws/studio-lab-examples/issues/118
#------------------------------------------------------------------------------#
import os
import subprocess
#Colors
ORANGE = '\033[33m'
GREEN = '\033[92m'
YELLOW = '\033[93m'
RED = '\033[91m'
DRED = '\033[31m'
MAGENTA = '\033[95m'
PINK = '\033[95m'
BLUE = '\033[94m'
DBLUE = '\033[34m'
VIOLET = '\033[35m'
DGREEN = '\033[32m'
PURPLE = '\033[95m'
NC = '\033[0m'
#------------------------------------------------------------------------------#
print(f"ⓘ {DBLUE}Initializing...{NC}")
## Setup
#-----#
! conda update -n base conda --all -y
# Dosify Script
! conda install -c curl dos2unix wget --all -y
! mkdir -p "$HOME/.scripts"
! curl -qfsSL "https://raw.githubusercontent.com/Azathothas/BugGPT-Tools/main/free-tiers/VPS/AWS%20SageMaker%20Studio%20(Lab)/Utils/setup_main.sh" -o "$HOME/.scripts/setup_main.sh" 
! dos2unix "$HOME/.scripts/setup_main.sh" 
! sed -e '/^$/d' -e 's/[[:space:]]*$//' -i "$HOME/.scripts/setup_main.sh" 
! chmod +x "$HOME/.scripts/setup_main.sh" 
# Open Terminal: Top Bar >> File >> NEW >> Terminal
# Copy Paste (remove #)
#bash "$HOME/.scripts/setup_main.sh" 
# Enter `Y` when prompted
#------------------------------------------------------------------------------#
## Temp Ephemeral SSH (tunshell)
#--------------------#
## Uncomment (remove # from curl cmd) & replace with yours
#! curl -sSf https://lets.tunshell.com/init.sh | sh -s -- T lcYKnfG2BBMyW1e7d3cAMg Lsjc8xX0folfNue7piHVbL eu.relay.tunshell.com

#------------------------------------------------------------------------------#
print(f"ⓘ {DGREEN}Initialized{NC}")
# Out:
# ⓘ Initializing...
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |            2_gnu          23 KB  conda-forge
#     boltons-23.0.0             |     pyhd8ed1ab_0         296 KB  conda-forge
#     brotli-1.0.9               |       h166bdaf_8          18 KB  conda-forge
#     brotli-bin-1.0.9           |       h166bdaf_8          20 KB  conda-forge
#     bzip2-1.0.8                |       h7f98852_4         484 KB  conda-forge
#     cffi-1.15.1                |   py39he91dace_3         229 KB  conda-forge
#     charset-normalizer-3.1.0   |     pyhd8ed1ab_0          44 KB  conda-forge
#     colorama-0.4.6             |     pyhd8ed1ab_0          25 KB  conda-forge
#     conda-23.5.0               |   py39hf3d152e_1         994 KB  conda-forge
#     conda-package-handling-2.0.2|     pyh38be061_0         247 KB  conda-forge
#     conda-package-streaming-0.8.0|     pyhd8ed1ab_0          18 KB  conda-forge
#     cryptography-41.0.1        |   py39hd4f0224_0         1.8 MB  conda-forge
#     idna-3.4                   |     pyhd8ed1ab_0          55 KB  conda-forge
#     jsonpatch-1.32             |     pyhd8ed1ab_0          14 KB  conda-forge
#     jsonpointer-2.0            |             py_0           9 KB  conda-forge
#     ld_impl_linux-64-2.40      |       h41732ed_0         688 KB  conda-forge
#     libbrotlicommon-1.0.9      |       h166bdaf_8          66 KB  conda-forge
#     libbrotlidec-1.0.9         |       h166bdaf_8          33 KB  conda-forge
#     libbrotlienc-1.0.9         |       h166bdaf_8         288 KB  conda-forge
#     libffi-3.4.2               |       h7f98852_5          57 KB  conda-forge
#     libgcc-ng-13.1.0           |       he5830b7_0         758 KB  conda-forge
#     libgomp-13.1.0             |       he5830b7_0         409 KB  conda-forge
#     libnsl-2.0.0               |       h7f98852_0          31 KB  conda-forge
#     libstdcxx-ng-13.1.0        |       hfd8a6a1_0         3.7 MB  conda-forge
#     libuuid-2.38.1             |       h0b41bf4_0          33 KB  conda-forge
#     libzlib-1.2.13             |       h166bdaf_4          64 KB  conda-forge
#     packaging-23.1             |     pyhd8ed1ab_0          45 KB  conda-forge
#     pip-23.1.2                 |     pyhd8ed1ab_0         1.3 MB  conda-forge
#     pluggy-1.0.0               |     pyhd8ed1ab_5          16 KB  conda-forge
#     pycosat-0.6.4              |   py39hb9d737c_1         108 KB  conda-forge
#     pycparser-2.21             |     pyhd8ed1ab_0         100 KB  conda-forge
#     pyopenssl-23.2.0           |     pyhd8ed1ab_1         126 KB  conda-forge
#     pysocks-1.7.1              |     pyha2e5f31_6          19 KB  conda-forge
#     python-3.9.16              |h2782a2a_0_cpython        23.0 MB  conda-forge
#     python_abi-3.9             |           3_cp39           6 KB  conda-forge
#     readline-8.2               |       h8228510_1         275 KB  conda-forge
#     requests-2.31.0            |     pyhd8ed1ab_0          55 KB  conda-forge
#     ruamel.yaml-0.17.31        |   py39hd1e30aa_0         196 KB  conda-forge
#     ruamel.yaml.clib-0.2.7     |   py39h72bdee0_1         140 KB  conda-forge
#     setuptools-67.7.2          |     pyhd8ed1ab_0         569 KB  conda-forge
#     tk-8.6.12                  |       h27826a3_0         3.3 MB  conda-forge
#     toolz-0.12.0               |     pyhd8ed1ab_0          48 KB  conda-forge
#     tqdm-4.65.0                |     pyhd8ed1ab_1          86 KB  conda-forge
#     tzdata-2023c               |       h71feb2d_0         115 KB  conda-forge
#     urllib3-2.0.3              |     pyhd8ed1ab_0          96 KB  conda-forge
#     wheel-0.40.0               |     pyhd8ed1ab_0          54 KB  conda-forge
#     xz-5.2.6                   |       h166bdaf_0         409 KB  conda-forge
#     zstandard-0.19.0           |   py39h29414ee_1         373 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        40.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   boltons            conda-forge/noarch::boltons-23.0.0-pyhd8ed1ab_0
#   brotli             conda-forge/linux-64::brotli-1.0.9-h166bdaf_8
#   brotli-bin         conda-forge/linux-64::brotli-bin-1.0.9-h166bdaf_8
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h7f98852_4
#   conda-package-str~ conda-forge/noarch::conda-package-streaming-0.8.0-pyhd8ed1ab_0
#   jsonpatch          conda-forge/noarch::jsonpatch-1.32-pyhd8ed1ab_0
#   jsonpointer        conda-forge/noarch::jsonpointer-2.0-py_0
#   libbrotlicommon    conda-forge/linux-64::libbrotlicommon-1.0.9-h166bdaf_8
#   libbrotlidec       conda-forge/linux-64::libbrotlidec-1.0.9-h166bdaf_8
#   libbrotlienc       conda-forge/linux-64::libbrotlienc-1.0.9-h166bdaf_8
#   libnsl             conda-forge/linux-64::libnsl-2.0.0-h7f98852_0
#   libsqlite          conda-forge/linux-64::libsqlite-3.42.0-h2797004_0
#   libuuid            conda-forge/linux-64::libuuid-2.38.1-h0b41bf4_0
#   libzlib            conda-forge/linux-64::libzlib-1.2.13-h166bdaf_4
#   packaging          conda-forge/noarch::packaging-23.1-pyhd8ed1ab_0
#   pluggy             conda-forge/noarch::pluggy-1.0.0-pyhd8ed1ab_5
#   ruamel.yaml        conda-forge/linux-64::ruamel.yaml-0.17.31-py39hd1e30aa_0
#   ruamel.yaml.clib   conda-forge/linux-64::ruamel.yaml.clib-0.2.7-py39h72bdee0_1
#   toolz              conda-forge/noarch::toolz-0.12.0-pyhd8ed1ab_0
#   zstandard          conda-forge/linux-64::zstandard-0.19.0-py39h29414ee_1
#   zstd               conda-forge/linux-64::zstd-1.5.2-h3eb15da_6
#
# The following packages will be REMOVED:
#
#   brotlipy-0.7.0-py39h3811e60_1001
#   chardet-4.0.0-py39hf3d152e_1
#   ruamel_yaml-0.15.80-py39h3811e60_1004
#   six-1.16.0-pyh6c4a22f_0
#   sqlite-3.36.0-h9cd32fc_2
#   yaml-0.2.5-h516909a_0
#   zlib-1.2.11-h516909a_1010
#
# The following packages will be UPDATED:
#
#   _openmp_mutex                                   4.5-1_gnu --> 4.5-2_gnu
#   ca-certificates                      2021.5.30-ha878542_0 --> 2023.5.7-hbcca054_0
#   certifi            conda-forge/linux-64::certifi-2021.5.~ --> conda-forge/noarch::certifi-2023.5.7-pyhd8ed1ab_0
#   cffi                                1.14.6-py39h4bc2ebd_1 --> 1.15.1-py39he91dace_3
#   charset-normalizer                     2.0.0-pyhd8ed1ab_0 --> 3.1.0-pyhd8ed1ab_0
#   colorama                               0.4.4-pyh9f0ad1d_0 --> 0.4.6-pyhd8ed1ab_0
#   conda                               4.10.3-py39hf3d152e_2 --> 23.5.0-py39hf3d152e_1
#   conda-package-han~ conda-forge/linux-64::conda-package-h~ --> conda-forge/noarch::conda-package-handling-2.0.2-pyh38be061_0
#   cryptography                         3.4.7-py39hbca0aa6_0 --> 41.0.1-py39hd4f0224_0
#   idna                                     3.1-pyhd3deb0d_0 --> 3.4-pyhd8ed1ab_0
#   ld_impl_linux-64                        2.36.1-hea4e1c9_2 --> 2.40-h41732ed_0
#   libffi                                   3.4.2-h9c3ff4c_4 --> 3.4.2-h7f98852_5
#   libgcc-ng                               11.2.0-h1d223b6_9 --> 13.1.0-he5830b7_0
#   libgomp                                 11.2.0-h1d223b6_9 --> 13.1.0-he5830b7_0
#   libstdcxx-ng                            11.2.0-he4da1e4_9 --> 13.1.0-hfd8a6a1_0
#   ncurses                                    6.2-h58526e2_4 --> 6.4-hcb278e6_0
#   openssl                                 1.1.1l-h7f98852_0 --> 3.1.1-hd590300_1
#   pip                                   21.2.4-pyhd8ed1ab_0 --> 23.1.2-pyhd8ed1ab_0
#   pycosat                           0.6.3-py39h3811e60_1006 --> 0.6.4-py39hb9d737c_1
#   pycparser                               2.20-pyh9f0ad1d_2 --> 2.21-pyhd8ed1ab_0
#   pyopenssl                             20.0.1-pyhd8ed1ab_0 --> 23.2.0-pyhd8ed1ab_1
#   pysocks            conda-forge/linux-64::pysocks-1.7.1-p~ --> conda-forge/noarch::pysocks-1.7.1-pyha2e5f31_6
#   python                           3.9.7-hb7a2778_2_cpython --> 3.9.16-h2782a2a_0_cpython
#   python_abi                                     3.9-2_cp39 --> 3.9-3_cp39
#   readline                                   8.1-h46c0cb4_0 --> 8.2-h8228510_1
#   requests                              2.26.0-pyhd8ed1ab_0 --> 2.31.0-pyhd8ed1ab_0
#   setuptools         conda-forge/linux-64::setuptools-58.0~ --> conda-forge/noarch::setuptools-67.7.2-pyhd8ed1ab_0
#   tk                                      8.6.11-h27826a3_1 --> 8.6.12-h27826a3_0
#   tqdm                                  4.62.3-pyhd8ed1ab_0 --> 4.65.0-pyhd8ed1ab_1
#   tzdata                                   2021a-he74cb21_1 --> 2023c-h71feb2d_0
#   urllib3                               1.26.7-pyhd8ed1ab_0 --> 2.0.3-pyhd8ed1ab_0
#   wheel                                 0.37.0-pyhd8ed1ab_1 --> 0.40.0-pyhd8ed1ab_0
#   xz                                       5.2.5-h516909a_1 --> 5.2.6-h166bdaf_0
#
#
#
# Downloading and Extracting Packages
# jsonpatch-1.32       | 14 KB     | ##################################### | 100%
# charset-normalizer-3 | 44 KB     | ##################################### | 100%
# conda-23.5.0         | 994 KB    | ##################################### | 100%
# cffi-1.15.1          | 229 KB    | ##################################### | 100%
# _openmp_mutex-4.5    | 23 KB     | ##################################### | 100%
# setuptools-67.7.2    | 569 KB    | ##################################### | 100%
# xz-5.2.6             | 409 KB    | ##################################### | 100%
# libuuid-2.38.1       | 33 KB     | ##################################### | 100%
# idna-3.4             | 55 KB     | ##################################### | 100%
# wheel-0.40.0         | 54 KB     | ##################################### | 100%
# pycosat-0.6.4        | 108 KB    | ##################################### | 100%
# libffi-3.4.2         | 57 KB     | ##################################### | 100%
# conda-package-handli | 247 KB    | ##################################### | 100%
# libnsl-2.0.0         | 31 KB     | ##################################### | 100%
# toolz-0.12.0         | 48 KB     | ##################################### | 100%
# ruamel.yaml-0.17.31  | 196 KB    | ##################################### | 100%
# pip-23.1.2           | 1.3 MB    | ##################################### | 100%
# tzdata-2023c         | 115 KB    | ##################################### | 100%
# pyopenssl-23.2.0     | 126 KB    | ##################################### | 100%
# tk-8.6.12            | 3.3 MB    | ##################################### | 100%
# brotli-1.0.9         | 18 KB     | ##################################### | 100%
# pysocks-1.7.1        | 19 KB     | ##################################### | 100%
# libgomp-13.1.0       | 409 KB    | ##################################### | 100%
# pluggy-1.0.0         | 16 KB     | ##################################### | 100%
# libbrotlicommon-1.0. | 66 KB     | ##################################### | 100%
# libbrotlidec-1.0.9   | 33 KB     | ##################################### | 100%
# colorama-0.4.6       | 25 KB     | ##################################### | 100%
# jsonpointer-2.0      | 9 KB      | ##################################### | 100%
# cryptography-41.0.1  | 1.8 MB    | ##################################### | 100%
# libstdcxx-ng-13.1.0  | 3.7 MB    | ##################################### | 100%
# zstandard-0.19.0     | 373 KB    | ##################################### | 100%
# ruamel.yaml.clib-0.2 | 140 KB    | ##################################### | 100%
# libgcc-ng-13.1.0     | 758 KB    | ##################################### | 100%
# ld_impl_linux-64-2.4 | 688 KB    | ##################################### | 100%
# boltons-23.0.0       | 296 KB    | ##################################### | 100%
# python-3.9.16        | 23.0 MB   | ##################################### | 100%
# requests-2.31.0      | 55 KB     | ##################################### | 100%
# bzip2-1.0.8          | 484 KB    | ##################################### | 100%
# libbrotlienc-1.0.9   | 288 KB    | ##################################### | 100%
# pycparser-2.21       | 100 KB    | ##################################### | 100%
# urllib3-2.0.3        | 96 KB     | ##################################### | 100%
# conda-package-stream | 18 KB     | ##################################### | 100%
# libzlib-1.2.13       | 64 KB     | ##################################### | 100%
# brotli-bin-1.0.9     | 20 KB     | ##################################### | 100%
# readline-8.2         | 275 KB    | ##################################### | 100%
# packaging-23.1       | 45 KB     | ##################################### | 100%
# tqdm-4.65.0          | 86 KB     | ##################################### | 100%
# python_abi-3.9       | 6 KB      | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: failed
#
# EnvironmentNotWritableError: The current user does not have write permissions to the target environment.
#   environment location: /opt/conda
#   uid: 1000
#   gid: 100
#
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 23.5.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/studio-lab-user/.conda/envs/default
#
#   added / updated specs:
#     - dos2unix
#     - wget
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     asttokens-2.2.1            |     pyhd8ed1ab_0          27 KB  conda-forge
#     comm-0.1.3                 |     pyhd8ed1ab_0          11 KB  conda-forge
#     debugpy-1.6.7              |   py39h227be39_0         1.8 MB  conda-forge
#     executing-1.2.0            |     pyhd8ed1ab_0          24 KB  conda-forge
#     gcc_impl_linux-64-13.1.0   |       hc4be1a9_0        51.7 MB  conda-forge
#     ipykernel-6.23.1           |     pyh210e3f2_0         111 KB  conda-forge
#     ipython-8.14.0             |     pyh41d4057_0         570 KB  conda-forge
#     ipywidgets-8.0.6           |     pyhd8ed1ab_0         110 KB  conda-forge
#     jupyterlab_widgets-3.0.7   |     pyhd8ed1ab_1         169 KB  conda-forge
#     libgcc-devel_linux-64-13.1.0|       he3cc6c4_0         2.3 MB  conda-forge
#     libsanitizer-13.1.0        |       hfd8a6a1_0         3.9 MB  conda-forge
#     platformdirs-3.5.3         |     pyhd8ed1ab_0          18 KB  conda-forge
#     prompt_toolkit-3.0.38      |       hd8ed1ab_0           6 KB  conda-forge
#     psutil-5.9.5               |   py39h72bdee0_0         350 KB  conda-forge
#     pure_eval-0.2.2            |     pyhd8ed1ab_0          14 KB  conda-forge
#     pygments-2.15.1            |     pyhd8ed1ab_0         821 KB  conda-forge
#     pyzmq-25.1.0               |   py39hb257651_0         440 KB  conda-forge
#     stack_data-0.6.2           |     pyhd8ed1ab_0          26 KB  conda-forge
#     tornado-6.3.2              |   py39hd1e30aa_0         615 KB  conda-forge
#     typing-extensions-4.6.3    |       hd8ed1ab_0          10 KB  conda-forge
#     typing_extensions-4.6.3    |     pyha770c72_0          34 KB  conda-forge
#     widgetsnbextension-4.0.7   |     pyhd8ed1ab_0         828 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        63.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   asttokens          conda-forge/noarch::asttokens-2.2.1-pyhd8ed1ab_0
#   comm               conda-forge/noarch::comm-0.1.3-pyhd8ed1ab_0
#   executing          conda-forge/noarch::executing-1.2.0-pyhd8ed1ab_0
#   libsanitizer       conda-forge/linux-64::libsanitizer-13.1.0-hfd8a6a1_0
#   prompt_toolkit     conda-forge/noarch::prompt_toolkit-3.0.38-hd8ed1ab_0
#   psutil             conda-forge/linux-64::psutil-5.9.5-py39h72bdee0_0
#   pure_eval          conda-forge/noarch::pure_eval-0.2.2-pyhd8ed1ab_0
#   stack_data         conda-forge/noarch::stack_data-0.6.2-pyhd8ed1ab_0
#
# The following packages will be REMOVED:
#
#   anyio-3.6.2-pyhd8ed1ab_0
#   argon2-cffi-21.3.0-pyhd8ed1ab_0
#   argon2-cffi-bindings-21.2.0-py39hb9d737c_3
#   attrs-22.2.0-pyh71513ae_0
#   beautifulsoup4-4.12.0-pyha770c72_0
#   bleach-6.0.0-pyhd8ed1ab_0
#   cffi-1.15.1-py39he91dace_3
#   defusedxml-0.7.1-pyhd8ed1ab_0
#   flit-core-3.8.0-pyhd8ed1ab_0
#   idna-3.4-pyhd8ed1ab_0
#   importlib-metadata-6.1.0-pyha770c72_0
#   importlib_resources-5.12.0-pyhd8ed1ab_0
#   ipython_genutils-0.2.0-py_1
#   jinja2-3.1.2-pyhd8ed1ab_1
#   jsonschema-4.17.3-pyhd8ed1ab_0
#   jupyter_events-0.6.3-pyhd8ed1ab_0
#   jupyter_server-2.5.0-pyhd8ed1ab_0
#   jupyter_server_terminals-0.4.4-pyhd8ed1ab_1
#   jupyterlab_pygments-0.2.2-pyhd8ed1ab_0
#   markupsafe-2.1.2-py39h72bdee0_0
#   mistune-2.0.5-pyhd8ed1ab_0
#   nbclassic-0.5.5-pyh8b2e9e2_0
#   nbclient-0.7.3-pyhd8ed1ab_0
#   nbconvert-core-7.3.0-pyhd8ed1ab_2
#   nbformat-5.8.0-pyhd8ed1ab_0
#   notebook-6.5.3-pyha770c72_0
#   notebook-shim-0.2.2-pyhd8ed1ab_0
#   pandocfilters-1.5.0-pyhd8ed1ab_0
#   pkgutil-resolve-name-1.3.10-pyhd8ed1ab_0
#   prometheus_client-0.16.0-pyhd8ed1ab_0
#   pycparser-2.21-pyhd8ed1ab_0
#   pyrsistent-0.19.3-py39h72bdee0_0
#   python-fastjsonschema-2.16.3-pyhd8ed1ab_0
#   python-json-logger-2.0.7-pyhd8ed1ab_0
#   pyyaml-6.0-py39hb9d737c_5
#   rfc3339-validator-0.1.4-pyhd8ed1ab_0
#   rfc3986-validator-0.1.1-pyh9f0ad1d_0
#   send2trash-1.8.0-pyhd8ed1ab_0
#   sniffio-1.3.0-pyhd8ed1ab_0
#   soupsieve-2.3.2.post1-pyhd8ed1ab_0
#   terminado-0.17.1-pyh41d4057_0
#   tinycss2-1.2.1-pyhd8ed1ab_0
#   webencodings-0.5.1-py_1
#   websocket-client-1.5.1-pyhd8ed1ab_0
#   yaml-0.2.5-h7f98852_2
#   zipp-3.15.0-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   debugpy                              1.6.6-py39h227be39_0 --> 1.6.7-py39h227be39_0
#   gcc_impl_linux-64                       7.5.0-habd7529_20 --> 13.1.0-hc4be1a9_0
#   ipykernel          conda-forge/linux-64::ipykernel-6.4.2~ --> conda-forge/noarch::ipykernel-6.23.1-pyh210e3f2_0
#   ipython            conda-forge/linux-64::ipython-7.33.0-~ --> conda-forge/noarch::ipython-8.14.0-pyh41d4057_0
#   ipywidgets                             7.7.5-pyhd8ed1ab_0 --> 8.0.6-pyhd8ed1ab_0
#   jupyterlab_widgets                     1.1.4-pyhd8ed1ab_0 --> 3.0.7-pyhd8ed1ab_1
#   libgcc-devel_linu~                      7.5.0-hda03d7c_20 --> 13.1.0-he3cc6c4_0
#   libgcc-ng                              12.2.0-h65d4601_19 --> 13.1.0-he5830b7_0
#   libgomp                                12.2.0-h65d4601_19 --> 13.1.0-he5830b7_0
#   libsqlite                               3.40.0-h753d276_0 --> 3.42.0-h2797004_0
#   libstdcxx-ng                           12.2.0-h46fd767_19 --> 13.1.0-hfd8a6a1_0
#   ncurses                                    6.3-h27087fc_1 --> 6.4-hcb278e6_0
#   packaging                               23.0-pyhd8ed1ab_0 --> 23.1-pyhd8ed1ab_0
#   pip                                   21.2.4-pyhd8ed1ab_0 --> 23.1.2-pyhd8ed1ab_0
#   platformdirs                           3.2.0-pyhd8ed1ab_0 --> 3.5.3-pyhd8ed1ab_0
#   pygments                              2.14.0-pyhd8ed1ab_0 --> 2.15.1-pyhd8ed1ab_0
#   pyzmq                               25.0.2-py39h0be026e_0 --> 25.1.0-py39hb257651_0
#   setuptools                            67.6.1-pyhd8ed1ab_0 --> 67.7.2-pyhd8ed1ab_0
#   tornado                                6.2-py39hb9d737c_1 --> 6.3.2-py39hd1e30aa_0
#   typing-extensions                        4.5.0-hd8ed1ab_0 --> 4.6.3-hd8ed1ab_0
#   typing_extensions                      4.5.0-pyha770c72_0 --> 4.6.3-pyha770c72_0
#   widgetsnbextension                     3.6.4-pyhd8ed1ab_0 --> 4.0.7-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages
# debugpy-1.6.7        | 1.8 MB    | ##################################### | 100%
# typing-extensions-4. | 10 KB     | ##################################### | 100%
# asttokens-2.2.1      | 27 KB     | ##################################### | 100%
# ipywidgets-8.0.6     | 110 KB    | ##################################### | 100%
# libsanitizer-13.1.0  | 3.9 MB    | ##################################### | 100%
# gcc_impl_linux-64-13 | 51.7 MB   | ##################################### | 100%
# stack_data-0.6.2     | 26 KB     | ##################################### | 100%
# pygments-2.15.1      | 821 KB    | ##################################### | 100%
# typing_extensions-4. | 34 KB     | ##################################### | 100%
# platformdirs-3.5.3   | 18 KB     | ##################################### | 100%
# ipython-8.14.0       | 570 KB    | ##################################### | 100%
# psutil-5.9.5         | 350 KB    | ##################################### | 100%
# libgcc-devel_linux-6 | 2.3 MB    | ##################################### | 100%
# executing-1.2.0      | 24 KB     | ##################################### | 100%
# tornado-6.3.2        | 615 KB    | ##################################### | 100%
# pyzmq-25.1.0         | 440 KB    | ##################################### | 100%
# comm-0.1.3           | 11 KB     | ##################################### | 100%
# ipykernel-6.23.1     | 111 KB    | ##################################### | 100%
# widgetsnbextension-4 | 828 KB    | ##################################### | 100%
# jupyterlab_widgets-3 | 169 KB    | ##################################### | 100%
# pure_eval-0.2.2      | 14 KB     | ##################################### | 100%
# prompt_toolkit-3.0.3 | 6 KB      | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# dos2unix: converting file /home/studio-lab-user/.scripts/setup_main.sh to Unix format...
# ⓘ Initialized
